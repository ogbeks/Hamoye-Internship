# %%
#This was carried out by Ogbekile Chukwudi.
#Importing the python library
import numpy as np 
import pandas as pd # data processing,

# %%
#Importing the dataset
#df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv')
df=pd.read_csv(r'C:\Users\Blessing\Downloads\energydata_complete.csv')
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
#Checking to see for each column information 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
#More description of the dataset
df.describe(include='all')
# Out:
#                        date    Appliances        lights            T1  \
# count                 19735  19735.000000  19735.000000  19735.000000
# unique                19735           NaN           NaN           NaN
# top     2016-01-20 16:40:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN     97.694958      3.801875     21.686571
# std                     NaN    102.524891      7.935988      1.606066
# min                     NaN     10.000000      0.000000     16.790000
# 25%                     NaN     50.000000      0.000000     20.760000
# 50%                     NaN     60.000000      0.000000     21.600000
# 75%                     NaN    100.000000      0.000000     22.600000
# max                     NaN   1080.000000     70.000000     26.260000
#
#                 RH_1            T2          RH_2            T3          RH_3  \
# ...

# %%
df.shape
# Out:
# (19735, 29)

# %%
#Ascertain the presence of NAN values in the datasets
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
# Correlations amogst the independent variables with the Appliances Target
sample_corr =(df.corr()['Appliances'].sort_values(ascending = True))
#Absolute correlation
#sample_corr =(abs(df.corr()['Appliances']).sort_values(ascending = True))
print(sample_corr)
# Out:
# RH_out        -0.152282
# RH_8          -0.094039
# RH_6          -0.083178
# RH_2          -0.060465
# RH_7          -0.055642
# RH_9          -0.051462
# Press_mm_hg   -0.034885
# rv1           -0.011145
# rv2           -0.011145
# Visibility     0.000230
# RH_5           0.006955
# T9             0.010010
# Tdewpoint      0.015353
# RH_4           0.016965
# T5             0.019760
# T7             0.025801
# RH_3           0.036292
# T8             0.039572
# T4             0.040281
# T1             0.055447
# T3             0.085060
# RH_1           0.086031
# Windspeed      0.087122
# T_out          0.099155
# T6             0.117638
# T2             0.120073
# lights         0.197278
# Appliances     1.000000
# Name: Appliances, dtype: float64

# %%
#select a sample of the dataset
simple_linear_reg_df = df[[ 'Appliances', 'T1']].sample(1500, random_state=42)
#regression plot
sns.regplot(x= 'Appliances', y= 'T1',data=simple_linear_reg_df)

# %%
x1=df['T1']
y=df['Appliances']

# Add a constant. Essentially, we are adding a new column (equal in lenght to x), which consists only of 1s
x = sm.add_constant(x1)
# Fit the model, according to the OLS (ordinary least squares) method with a dependent variable y and an idependent x
results = sm.OLS(y,x).fit()
# Print a nice summary of the regression. That's one of the strong points of statsmodels -> the summaries
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Appliances   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     60.85
# Date:                Sun, 02 Aug 2020   Prob (F-statistic):           6.45e-15
# Time:                        19:12:59   Log-Likelihood:            -1.1935e+05
# No. Observations:               19735   AIC:                         2.387e+05
# Df Residuals:                   19733   BIC:                         2.387e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         20.9343      9.867      2.122      0.034       1.594      40.274
# ...

# %% [markdown]
# ## The task

# %%
#droping the date and light column
df.columns
#df.drop(df[['date','lights']], axis=1, inplace=True)
df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
#Importing the library to normalize the dataset
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
#Normalizing the datasets using the MinMaxScaler from Sklearn
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
features_df =normalised_df.drop(columns=['Appliances'])
target_col = normalised_df['Appliances']

# %%
#Importing the library that split the dataset into training and testing sets
from sklearn.model_selection import train_test_split

# %%
#Spliting the dataset into training and testing set with a ratio 70:30 and a randomizing factor of 42
X_train, X_test, y_train, y_test = train_test_split(features_df, target_col, test_size=0.3, random_state=42)

# %%
#Importing the method for linearRegression
from sklearn.linear_model import LinearRegression

# %%
#Performing the multi-linear regression of the features and the targets using the training set
regressor = LinearRegression()
regressor.fit(X_train, y_train)

y_predict = regressor.predict(X_test)

# %%
#Importing the metrics method from the Sklearn library
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
#Calculating the Mean absolute error
mae=mean_absolute_error(y_test, y_predict)
print('Mean Absolute error: ',round(mae,4))
# Out:
# Mean Absolute error:  0.0501

# %%
#Calculating the R - squared
r2_score_value = r2_score(y_test, y_predict)
print('R-squared score: ', round(r2_score_value,2))
# Out:
# R-squared score:  0.15

# %%
#Calculating the Residual sum of squares
rss = np.sum(np.square(y_test - y_predict))
print('Residual sum of squares: ', round(rss, 2))
# Out:
# Residual sum of squares:  45.35

# %%
#Calculating the  Mean Squared Error
mse = mean_squared_error(y_test, y_predict)
print('Mean Squared Error: ', round(mse,3))
# Out:
# Mean Squared Error:  0.008

# %%
#Calculating the Root Mean Squared Error
rmse = np.sqrt(mse)
print('Root Mean Squared Error: ', round(rmse,3))
# Out:
# Root Mean Squared Error:  0.088

# %% [markdown]
# ## Regularization of the model using Lasso and Ridge

# %%
#Importing the Lasso and Ridge linear model regularization.
from sklearn.linear_model import Lasso, Ridge

# %%
#Performing the Lasso and Ridge regularization of the model
lasso_reg =Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)

ridge_reg = Ridge(alpha=0.5)
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#Comparing the effect of the regularizations

def get_weight_df(model, features, col_name):
    weights= pd.Series(model.coef_, features.columns).sort_values()
    #print(model.coef_)
    #print(weights)
    weights_df = pd.DataFrame(weights).reset_index()
    #print(weights_df.columns)
    weights_df.columns=['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df

# %%
#getting the weight of the model co-efficient of the multi-linear regression analysis
linear_model_weights = get_weight_df(regressor, X_train, 'Linear_Model_Weight')
print(linear_model_weights)
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %%
#Getting the weight of the co-efficient of the Ridge regularization model
ridge_weights_df = get_weight_df(ridge_reg, X_train, 'Ridge_Weight')
print(ridge_weights_df)
# Out:
#        Features  Ridge_Weight
# 0          RH_2     -0.401134
# 1         T_out     -0.250765
# 2            T2     -0.193880
# 3            T9     -0.188584
# 4          RH_8     -0.156596
# 5        RH_out     -0.050541
# 6          RH_7     -0.046291
# 7          RH_9     -0.041701
# 8            T1     -0.021549
# 9            T5     -0.020727
# 10          rv1      0.000743
# 11          rv2      0.000743
# 12  Press_mm_hg      0.006516
# 13           T7      0.010021
# 14   Visibility      0.012032
# 15         RH_5      0.016176
# 16         RH_4      0.024168
# 17           T4      0.027006
# 18    Windspeed      0.030463
# 19         RH_6      0.035023
# 20    Tdewpoint      0.076668
# 21         RH_3      0.094976
# 22           T8      0.100754
# 23           T6      0.213316
# 24           T3      0.287408
# 25         RH_1      0.511932

# %%
#Getting the weight of the co-efficient of the Lasso regularization model
lasso_weights_df = get_weight_df(lasso_reg, X_train, 'Lasso_weight')
print(lasso_weights_df)
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %%
#Merging the dataframe of the linear_model weight, ridge_model weight and the Lasso_model weight
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
print(final_weights)
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          RH_2            -0.456698     -0.401134     -0.000000
# 1         T_out            -0.321860     -0.250765      0.000000
# 2            T2            -0.236178     -0.193880      0.000000
# 3            T9            -0.189941     -0.188584     -0.000000
# 4          RH_8            -0.157595     -0.156596     -0.000110
# 5        RH_out            -0.077671     -0.050541     -0.049557
# 6          RH_7            -0.044614     -0.046291     -0.000000
# 7          RH_9            -0.039800     -0.041701     -0.000000
# 8            T5            -0.015657     -0.020727     -0.000000
# 9            T1            -0.003281     -0.021549      0.000000
# 10          rv1             0.000770      0.000743     -0.000000
# 11          rv2             0.000770      0.000743     -0.000000
# 12  Press_mm_hg             0.006839      0.006516     -0.000000
# ...

# %%
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          RH_2            -0.456698     -0.401134     -0.000000
# 1         T_out            -0.321860     -0.250765      0.000000
# 2            T2            -0.236178     -0.193880      0.000000
# 3            T9            -0.189941     -0.188584     -0.000000
# 4          RH_8            -0.157595     -0.156596     -0.000110
# 5        RH_out            -0.077671     -0.050541     -0.049557
# 6          RH_7            -0.044614     -0.046291     -0.000000
# 7          RH_9            -0.039800     -0.041701     -0.000000
# 8            T5            -0.015657     -0.020727     -0.000000
# 9            T1            -0.003281     -0.021549      0.000000
# 10          rv1             0.000770      0.000743     -0.000000
# 11          rv2             0.000770      0.000743     -0.000000
# 12  Press_mm_hg             0.006839      0.006516     -0.000000
# ...

# %%
print(' min: {}, \n max: {}'.format( final_weights.head(1), final_weights.tail(1)))
# Out:
#  min:   Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0     RH_2            -0.456698     -0.401134          -0.0,
#  max:    Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 25     RH_1             0.553547      0.511932       0.01788

# %%
X_train.head()
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 9129   0.497360  0.236767  0.122850  0.565939  0.373878  0.303474  0.476577
# 2453   0.286167  0.482616  0.188999  0.669978  0.217957  0.735317  0.270270
# 9152   0.422386  0.230529  0.057427  0.606430  0.373878  0.338059  0.414414
# 12694  0.560718  0.446840  0.280834  0.704002  0.514290  0.515189  0.540541
# 16952  0.835269  0.422071  1.000000  0.318493  0.745383  0.459106  0.900901
#
#            RH_4        T5      RH_5  ...        T9      RH_9     T_out  \
# 9129   0.264760  0.408027  0.159533  ...  0.475893  0.376380  0.168810
# 2453   0.691421  0.178691  0.333576  ...  0.240375  0.703504  0.262594
# 9152   0.236449  0.378404  0.151639  ...  0.468262  0.409803  0.110397
# 12694  0.486556  0.509317  0.424604  ...  0.561915  0.340784  0.444802
# 16952  0.516432  0.748845  0.455819  ...  0.854318  0.633278  0.849946
#
#        Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1  \
# ...

# %%
#Performing the linear regression of T6 against T2 
x = df[['T2']]
y = df[['T6']]

x_lin_train, x_lin_test, y_lin_train, y_lin_test = train_test_split(x,y, test_size=0.3, random_state=42)
lin_reg=LinearRegression()
lin_reg.fit(x_lin_train, y_lin_train)
y_pred_lin = lin_reg.predict(x_lin_test)

r2_score_lin = r2_score(y_lin_test, y_pred_lin)
print("R squared score of linear model: ",round(r2_score_lin,3))

mae_lin = mean_absolute_error(y_lin_test, y_pred_lin)
print("MAE: ", mae_lin.round(2))

mse_lin = mean_squared_error(y_lin_test, y_pred_lin)
print("MSE: ",mse_lin.round(2))

rss_lin = np.sum(np.square(y_lin_test - y_pred_lin))
print('Residual sum of squares: ', round(rss_lin, 2))

print("RMSE: ",np.sqrt(mse_lin).round(4))
# Out:
# R squared score of linear model:  0.643
# MAE:  2.82
# MSE:  13.18
# Residual sum of squares:  T6    78033.97
# dtype: float64
# RMSE:  3.6303

# %%
#Determine the ridge_regression RMSE
ridge_regs = Ridge(alpha=0.4)
ridge_regs.fit(X_train, y_train)
y_ridge_predict=ridge_regs.predict(X_test)
mse_ridge = mean_squared_error(y_test, y_ridge_predict)
rmse_ridge = np.sqrt(mse_ridge)
print("RMSE :", rmse_ridge)
# Out:
# RMSE : 0.08753385704628003

# %%
#Determine the number of co-efficient of Lasso that is non-zero
lasso_reg =Lasso(alpha=0.001)
lasso_reg.fit(X_train, y_train)
y_lasso_predict=lasso_reg.predict(X_test)

lasso_weight= lasso_reg.coef_
lasso_weight
count=0
for i in lasso_weight:
    if i !=0:
        count+=1
print(count)
# Out:
# 4

# %%
#Determine the new RMSE of Lasso regression
mse_lasso = mean_squared_error(y_test, y_lasso_predict)
rmse_lasso = np.sqrt(mse_lasso)
print("RMSE lasso: ", rmse_lasso.round(3))
# Out:
# RMSE lasso:  0.094
